# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
import matplotlib.pyplot as plt

class NomaEnvironment:
    def __init__(self, num_pairs=3, P_total=20, min_power_ratio=0.1, noise_power=1e-6, eavesdropper_scale=0.5, alpha=0.5, mimo_dim=2):
        self.num_pairs = num_pairs
        self.P_total = P_total
        self.min_power_ratio = min_power_ratio
        self.noise_power = noise_power
        self.eavesdropper_scale = eavesdropper_scale
        self.alpha = alpha  # SIC imperfection factor at eavesdropper
        self.mimo_dim = mimo_dim  # Dimension of MIMO channel matrices
        np.random.seed(5)  # Fixed seed for consistent channel gains

        # Initialize dynamic power thresholds (PT1, PT2) and rate thresholds (RT1, RT2)
        self.PT1 = np.ones(num_pairs) * (P_total / (2 * num_pairs))  # Initial equal allocation
        self.PT2 = np.ones(num_pairs) * (P_total / (2 * num_pairs))  # Initial equal allocation

        # Modified rate thresholds as requested: RT1 = 1.0, RT2 = 0.3
        self.RT1 = np.ones(num_pairs) * 1.0  # Threshold for stronger user
        self.RT2 = np.ones(num_pairs) * 0.3  # Modified: Lower threshold for weaker user (0.3 instead of 0.5)

        # Generate channel matrices for each pair
        self.channel_matrices = self.generate_channel_matrices()
        self.reset()

    def generate_channel_matrices(self):
        """Generate MIMO channel matrices for each pair"""
        pairs = []
        pairing_info = []

        for i in range(self.num_pairs):
            # Generate channel matrices for each pair
            H1 = np.abs((np.random.randn(self.mimo_dim, self.mimo_dim) + 1j * np.random.randn(self.mimo_dim, self.mimo_dim)) / np.sqrt(2))
            H2 = np.abs((np.random.randn(self.mimo_dim, self.mimo_dim) + 1j * np.random.randn(self.mimo_dim, self.mimo_dim)) / np.sqrt(2))
            H1e = np.abs((np.random.randn(self.mimo_dim, self.mimo_dim) + 1j * np.random.randn(self.mimo_dim, self.mimo_dim)) / np.sqrt(2))
            H2e = np.abs((np.random.randn(self.mimo_dim, self.mimo_dim) + 1j * np.random.randn(self.mimo_dim, self.mimo_dim)) / np.sqrt(2))

            # Calculate channel gains
            H1_gain = self.calculate_channel_gain(H1)
            H2_gain = self.calculate_channel_gain(H2)

            # Ensure User 1 has higher gain to BS (for NOMA ordering)
            if H1_gain < H2_gain:
                H1, H2 = H2, H1
                H1e, H2e = H2e, H1e
                H1_gain = self.calculate_channel_gain(H1)
                H2_gain = self.calculate_channel_gain(H2)

            H1e_gain = self.calculate_channel_gain(H1e)
            H2e_gain = self.calculate_channel_gain(H2e)

            pairs.append((H1, H2, H1e, H2e))
            pairing_info.append((H1_gain, H2_gain, H1e_gain, H2e_gain))

        print("\n===== Channel Gains =====")
        for i, (h1, h2, h1e, h2e) in enumerate(pairing_info):
            print(f"Pair {i+1}:")
            print(f"h1: {h1:.4f}")
            print(f"h2: {h2:.4f}")
            print(f"h1e: {h1e:.4f}")
            print(f"h2e: {h2e:.4f}")

        return pairs

    def calculate_channel_gain(self, H):
        """Calculate channel gain from MIMO channel matrix"""
        return np.real(np.trace(np.matmul(H, H.conj().T))) / H.shape[0]

    def calculate_sinr(self, pair_idx, all_powers):
        """Calculate SINR for legitimate users and eavesdropper"""
        H1, H2, H1e, H2e = self.channel_matrices[pair_idx]
        H1_gain = self.calculate_channel_gain(H1)  # Stronger user to BS
        H2_gain = self.calculate_channel_gain(H2)  # Weaker user to BS
        H1e_gain = self.calculate_channel_gain(H1e)  # Stronger user to Eve
        H2e_gain = self.calculate_channel_gain(H2e)  # Weaker user to Eve

        P1, P2 = all_powers[pair_idx]
        Pn = all_powers[-1][0]  # Last element is Pn

        # SINR at Base Station (no artificial noise impact)
        # For stronger user (decoded first)
        SINR1 = (P1 * (H1_gain**2) ) / (P2 * (H2_gain**2) + self.noise_power)

        # For weaker user (decoded second) - after SIC
        SINR2 = (P2 * (H2_gain**2)) / ( self.alpha*(P1 * (H1_gain**2)) + self.noise_power)

        # SINR at Eavesdropper (with artificial noise impact)
        # For stronger user (decoded first)
        SINR1E = (P1 * (H1e_gain**2) ) / (P2 * (H2e_gain**2) + Pn * (H1e_gain**2) + self.noise_power)

        # For weaker user (decoded second) - imperfect SIC
        SINR2E = (P2 * (H2e_gain**2) ) / (Pn * (H2e_gain**2) + self.alpha * P1 * (H1e_gain**2) + self.noise_power)

        return SINR1, SINR2, SINR1E, SINR2E

    def calculate_rates(self, SINR1, SINR2, SINR1E, SINR2E):
        """Calculate achievable rates and secrecy rates"""
        # Legitimate channel rates
        R1 = np.log2(1 + SINR1)
        R2 = np.log2(1 + SINR2)

        # Eavesdropper channel rates
        R1E = np.log2(1 + SINR1E)
        R2E = np.log2(1 + SINR2E)

        # Secrecy rates (non-negative)
        SR1 = np.maximum(0, R1 - R1E)
        SR2 = np.maximum(0, R2 - R2E)

        return SR1, SR2, R1, R2, R1E, R2E

    def adjust_power_for_constraints(self, pair_idx, rates, powers, remaining_power):
        """
        Adjust power allocation to prioritize meeting constraints
        Returns: adjusted P1, P2, and remaining power
        """
        SR1, SR2, _, _, _, _ = rates
        P1, P2 = powers[pair_idx]
        PT1, PT2 = self.PT1[pair_idx], self.PT2[pair_idx]
        RT1, RT2 = self.RT1[pair_idx], self.RT2[pair_idx]

        power_adjusted = False

        # Check if constraints are met
        deficit1 = max(0, RT1 - SR1)
        deficit2 = max(0, RT2 - SR2)

        # Calculate available headroom for both users
        headroom1 = max(0, PT1 - P1)
        headroom2 = max(0, PT2 - P2)

        # Calculate how much to increase based on deficit
        # The larger the deficit, the larger the increase
        increase_factor = 0.4  # Increased from 0.3 to allocate more power

        # Special handling for Pair 2
        if pair_idx == 1:
            # For Pair 2, prioritize User 1 more aggressively
            if deficit1 > 0 and headroom1 > 0:
                # Prioritize stronger user in Pair 2
                increase_amount = min(remaining_power, headroom1,
                                     deficit1 * increase_factor * 1.5 * P1)  # 50% more increase
                if increase_amount > 0:
                    P1 += increase_amount
                    remaining_power -= increase_amount
                    power_adjusted = True

            if deficit2 > 0 and headroom2 > 0:
                # Then weaker user
                increase_amount = min(remaining_power, headroom2,
                                     deficit2 * increase_factor * P2)
                if increase_amount > 0:
                    P2 += increase_amount
                    remaining_power -= increase_amount
                    power_adjusted = True
        else:
            # For other pairs, prioritize weaker user first as they usually struggle more
            if deficit2 > 0 and headroom2 > 0:
                increase_amount = min(remaining_power, headroom2,
                                     deficit2 * increase_factor * P2)
                if increase_amount > 0:
                    P2 += increase_amount
                    remaining_power -= increase_amount
                    power_adjusted = True

            if deficit1 > 0 and headroom1 > 0:
                # Then stronger user
                increase_amount = min(remaining_power, headroom1,
                                     deficit1 * increase_factor * P1)
                if increase_amount > 0:
                    P1 += increase_amount
                    remaining_power -= increase_amount
                    power_adjusted = True

        return P1, P2, remaining_power, power_adjusted

    def balance_power_within_pair(self, pair_idx, rates, powers, remaining_power):
        """
        Reallocate power between users in the same pair when one exceeds its constraint
        and the other doesn't meet it. This function should be called within the step method.
        """
        SR1, SR2, _, _, _, _ = rates
        P1, P2 = powers
        RT1, RT2 = self.RT1[pair_idx], self.RT2[pair_idx]

        # Calculate excess/deficit for each user
        deficit1 = max(0, RT1 - SR1)  # How much user 1 is below threshold
        excess2 = max(0, SR2 - RT2)   # How much user 2 is above threshold

        deficit2 = max(0, RT2 - SR2)  # How much user 2 is below threshold
        excess1 = max(0, SR1 - RT1)   # How much user 1 is above threshold

        # Case 1: User 1 needs more, User 2 has excess
        if deficit1 > 0 and excess2 > 0 and SR2 > RT2 * 1.2:  # User 2 is 20% over threshold
            # Calculate power reduction for user 2 (proportional to excess)
            power_reduction = min(P2 * 0.2, P2 * excess2 / (RT2 * 3))
            P2 -= power_reduction
            P1 += power_reduction
            print(f"Pair {pair_idx+1}: Transferred {power_reduction:.4f}W from User 2 to User 1")

        # Case 2: User 2 needs more, User 1 has excess
        elif deficit2 > 0 and excess1 > 0 and SR1 > RT1 * 1.2:  # User 1 is 20% over threshold
            # Calculate power reduction for user 1 (proportional to excess)
            power_reduction = min(P1 * 0.2, P1 * excess1 / (RT1 * 3))
            P1 -= power_reduction
            P2 += power_reduction
            print(f"Pair {pair_idx+1}: Transferred {power_reduction:.4f}W from User 1 to User 2")

        # Case 3: Specific fix for Pair 2 - More aggressive power shifting
        if pair_idx == 1 and deficit1 > 0 and excess2 > 0:
            # Even more aggressive power transfer for Pair 2
            additional_shift = min(P2 * 0.15, 0.5)  # Up to 15% extra shift
            P2 -= additional_shift
            P1 += additional_shift
            print(f"Pair 2 Special Fix: Extra {additional_shift:.4f}W from User 2 to User 1")

        return P1, P2

    def apply_power_constraints(self, powers):
        """Apply power constraints including PT1 and PT2 limits and minimum power"""
        modified_powers = []

        # For each power allocation pair
        for i in range(len(powers) - 1):
            P1, P2 = powers[i]

            # Apply minimum power constraint
            min_power = self.min_power_ratio * self.P_total / (2 * self.num_pairs)
            P1 = max(P1, min_power)
            P2 = max(P2, min_power)

            # Apply maximum power constraints (PT1, PT2)
            P1 = min(P1, self.PT1[i])
            P2 = min(P2, self.PT2[i])

            modified_powers.append([P1, P2])

        # Add Pn (noise power) unchanged
        modified_powers.append(powers[-1])

        return modified_powers

    def adjust_thresholds_based_on_necessity(self, rates_info, powers_info):
      """Adjust thresholds based on constraint satisfaction and power usage efficiency"""
      # Check if we're receiving a list of rates for a single pair or for all pairs
      # If it's a single pair, we'll handle it differently
      single_pair_mode = False
      if len(rates_info) == 1 and isinstance(rates_info[0], tuple) and len(rates_info[0]) == 6:
          single_pair_mode = True
          pair_idx = 0  # Default to pair 0 unless specified
          if len(powers_info) == 2 and isinstance(powers_info[1], int):
              pair_idx = powers_info[1]
              powers_info = [powers_info[0]]

          # In single pair mode, rates_info is [(SR1, SR2, R1, R2, R1E, R2E)]
          # and powers_info is [[P1, P2]]
          SR1, SR2, _, _, _, _ = rates_info[0]
          P1, P2 = powers_info[0]
          RT1, RT2 = self.RT1[pair_idx], self.RT2[pair_idx]

          # Apply adjustment logic for this specific pair
          threshold_adjustments = []

          # Case 1: User exceeds threshold but just meets constraint
          if P1 > self.PT1[pair_idx] and 1.0 <= (SR1 / RT1) <= 1.2:
              # User needs this power to meet constraint - increase threshold
              adjustment = (P1 * 1.1) - self.PT1[pair_idx]
              threshold_adjustments.append((pair_idx, 0, adjustment))

          if P2 > self.PT2[pair_idx] and 1.0 <= (SR2 / RT2) <= 1.2:
              # User needs this power to meet constraint - increase threshold
              adjustment = (P2 * 1.1) - self.PT2[pair_idx]
              threshold_adjustments.append((pair_idx, 1, adjustment))

          # Case 2: User is using much less power than threshold but meeting constraint
          if P1 < self.PT1[pair_idx] * 0.7 and SR1 >= RT1:
              # User is efficient - can reduce threshold
              adjustment = (P1 * 1.2) - self.PT1[pair_idx]  # Negative adjustment
              threshold_adjustments.append((pair_idx, 0, adjustment))

          if P2 < self.PT2[pair_idx] * 0.7 and SR2 >= RT2:
              # User is efficient - can reduce threshold
              adjustment = (P2 * 1.2) - self.PT2[pair_idx]  # Negative adjustment
              threshold_adjustments.append((pair_idx, 1, adjustment))
      else:
          # Original implementation for multiple pairs
          threshold_adjustments = []

          for i in range(min(len(rates_info), len(powers_info), self.num_pairs)):
              SR1, SR2 = rates_info[i][0], rates_info[i][1]
              RT1, RT2 = self.RT1[i], self.RT2[i]
              P1, P2 = powers_info[i]

              # Case 1: User exceeds threshold but just meets constraint
              if P1 > self.PT1[i] and 1.0 <= (SR1 / RT1) <= 1.2:
                  # User needs this power to meet constraint - increase threshold
                  adjustment = (P1 * 1.1) - self.PT1[i]  # Amount to increase
                  threshold_adjustments.append((i, 0, adjustment))

              if P2 > self.PT2[i] and 1.0 <= (SR2 / RT2) <= 1.2:
                  # User needs this power to meet constraint - increase threshold
                  adjustment = (P2 * 1.1) - self.PT2[i]
                  threshold_adjustments.append((i, 1, adjustment))

              # Case 2: User is using much less power than threshold but meeting constraint
              if P1 < self.PT1[i] * 0.7 and SR1 >= RT1:
                  # User is efficient - can reduce threshold
                  adjustment = (P1 * 1.2) - self.PT1[i]  # Negative adjustment
                  threshold_adjustments.append((i, 0, adjustment))

              if P2 < self.PT2[i] * 0.7 and SR2 >= RT2:
                  # User is efficient - can reduce threshold
                  adjustment = (P2 * 1.2) - self.PT2[i]  # Negative adjustment
                  threshold_adjustments.append((i, 1, adjustment))

      # Apply the adjustments
      for pair_idx, user_idx, adjustment in threshold_adjustments:
          if user_idx == 0:
              self.PT1[pair_idx] += adjustment
              # Ensure minimum threshold
              self.PT1[pair_idx] = max(self.PT1[pair_idx], powers_info[0][0] * 1.05 if single_pair_mode else powers_info[pair_idx][0] * 1.05)
          else:
              self.PT2[pair_idx] += adjustment
              # Ensure minimum threshold
              self.PT2[pair_idx] = max(self.PT2[pair_idx], powers_info[0][1] * 1.05 if single_pair_mode else powers_info[pair_idx][1] * 1.05)

      # After adjustments, normalize to ensure total remains at P_total
      self.normalize_power_thresholds()

    def normalize_power_thresholds(self):
        """Ensure all power thresholds sum to exactly P_total"""
        total_pt = sum(self.PT1) + sum(self.PT2)

        if abs(total_pt - self.P_total) > 1e-6:  # Check with small tolerance
            # Scale all thresholds proportionally
            scale_factor = self.P_total / total_pt
            self.PT1 = self.PT1 * scale_factor
            self.PT2 = self.PT2 * scale_factor

        #from here
        # Ensure NOMA ordering principle: PT1 > PT2 for all pairs
        for i in range(self.num_pairs):
          # If PT1 is not greater than PT2, adjust them
          if self.PT1[i] <= self.PT2[i]:
              total = self.PT1[i] + self.PT2[i]
              # Ensure stronger user gets more power (e.g., 60-40 split)
              self.PT1[i] = total * 0.6
              self.PT2[i] = total * 0.4
        #until here

    def update_power_thresholds(self, pair_idx, sr1, sr2, p1, p2):
        """Update power thresholds (PT1, PT2) based on rate performance with improved reallocation"""
        # Power adjustment factors - more aggressive
        base_adjustment = 0.1  # Increased from 0.08

        # Deficit-based adjustment for constraint failing users
        sr1_deficit = max(0, self.RT1[pair_idx] - sr1)
        sr2_deficit = max(0, self.RT2[pair_idx] - sr2)

        # Calculate deficit ratio (how far from target)
        sr1_deficit_ratio = sr1_deficit / self.RT1[pair_idx] if self.RT1[pair_idx] > 0 else 0
        sr2_deficit_ratio = sr2_deficit / self.RT2[pair_idx] if self.RT2[pair_idx] > 0 else 0

        # For stronger user (User 1)
        if sr1 >= self.RT1[pair_idx] * 1.3:  # Exceeding threshold by 30%
            # User is achieving higher secrecy rate than needed - reduce power threshold
            self.PT1[pair_idx] = max(self.PT1[pair_idx] * (1 - base_adjustment),
                                p1 * 1.1)  # Don't reduce below current usage
        elif sr1 < self.RT1[pair_idx]:  # Not meeting threshold
            # Increase power threshold based on how far from target
            increase_factor = base_adjustment * (1 + 2 * sr1_deficit_ratio)
            self.PT1[pair_idx] = min(self.PT1[pair_idx] * (1 + increase_factor),
                                self.P_total / self.num_pairs * 1.5)  # Allow up to 1.5x share

        # For weaker user (User 2)
        if sr2 >= self.RT2[pair_idx] * 1.3:  # Exceeding threshold by 30%
            # User is achieving higher secrecy rate than needed - reduce power threshold
            self.PT2[pair_idx] = max(self.PT2[pair_idx] * (1 - base_adjustment),
                                p2 * 1.1)  # Don't reduce below current usage
        elif sr2 < self.RT2[pair_idx]:  # Not meeting threshold
            # Increase power threshold based on how far from target
            increase_factor = base_adjustment * (1 + 2 * sr2_deficit_ratio)
            self.PT2[pair_idx] = min(self.PT2[pair_idx] * (1 + increase_factor),
                                self.P_total / self.num_pairs * 1.5)  # Allow up to 1.5x share

        # If both exceed threshold, prioritize stronger user having adequate power
        # This is specific to NOMA requirements
        if sr1 >= self.RT1[pair_idx] and sr2 >= self.RT2[pair_idx]:
            # Adjust power thresholds to favor user 1 slightly (NOMA principle)
            total_threshold = self.PT1[pair_idx] + self.PT2[pair_idx]
            self.PT1[pair_idx] = total_threshold * 0.55  # Give stronger user slight advantage
            self.PT2[pair_idx] = total_threshold * 0.45

        # Special case for Pair 2 where we see issues (target specific problem area)
        # Can be generalized for all pairs with similar conditions
        if pair_idx == 1 and sr1 < self.RT1[pair_idx] and sr2 > self.RT2[pair_idx] * 1.5:
            # User 2 exceeds by a lot, User 1 is below threshold
            # Strongly adjust thresholds to favor User 1
            total_threshold = self.PT1[pair_idx] + self.PT2[pair_idx]
            self.PT1[pair_idx] = total_threshold * 0.65  # Give much more power to User 1
            self.PT2[pair_idx] = total_threshold * 0.35

        # Normalize thresholds periodically to ensure total is P_total
        # This is now handled by normalize_power_thresholds() called after all updates

    def calculate_constraint_reward(self, rates, pair_idx):
        """
        Calculate rewards specifically focused on meeting constraints.
        Can be called within the step function's reward calculation.
        """
        SR1, SR2, R1, R2, R1E, R2E = rates
        RT1, RT2 = self.RT1[pair_idx], self.RT2[pair_idx]

        # Base constraint reward/penalty
        constraint_weight = 50  # Very high weight to force constraint satisfaction
        constraint_reward = 0

        # Calculate how close each user is to meeting its constraint
        sr1_ratio = SR1 / RT1 if RT1 > 0 else 1.0
        sr2_ratio = SR2 / RT2 if RT2 > 0 else 1.0

        # For stronger user (User 1)
        if sr1_ratio >= 1.0:  # Constraint met
            # Modest reward for meeting constraint (using diminishing returns beyond 100%)
            constraint_reward += constraint_weight * min(1.5, sr1_ratio)
        else:
            # Severe penalty for not meeting constraint (increases exponentially as we get further from target)
            deficit_factor = (1 - sr1_ratio) ** 2  # Squared to increase penalty for larger deficits
            constraint_reward -= constraint_weight * 2 * deficit_factor

        # For weaker user (User 2)
        if sr2_ratio >= 1.0:  # Constraint met
            # Modest reward for meeting constraint
            constraint_reward += constraint_weight * min(1.5, sr2_ratio)
        else:
            # Severe penalty for not meeting constraint
            deficit_factor = (1 - sr2_ratio) ** 2
            constraint_reward -= constraint_weight * 2 * deficit_factor

        # Special handling for Pair 2
        if pair_idx == 1:
            # For Pair 2, we need to specifically handle User 1 not meeting constraints
            if sr1_ratio < 1.0:
                # Extra penalty for Pair 2's User 1 not meeting constraint
                constraint_reward -= constraint_weight * (1 - sr1_ratio) * 2

            # If User 2 is greatly exceeding while User 1 is failing, huge penalty
            if sr1_ratio < 0.9 and sr2_ratio > 1.5:
                constraint_reward -= constraint_weight * 3

        # Global constraint satisfaction bonus
        # If all constraints in this pair are met, add a bonus
        if sr1_ratio >= 1.0 and sr2_ratio >= 1.0:
            constraint_reward += constraint_weight * 0.5

        return constraint_reward

    def balance_secrecy_rates(self, rates, powers):
        """Balance secrecy rates across users while ensuring constraints are met"""
        all_sr = []
        for i in range(self.num_pairs):
            SR1, SR2 = rates[i][0], rates[i][1]
            RT1, RT2 = self.RT1[i], self.RT2[i]
            all_sr.extend([SR1, SR2])

        # Calculate mean secrecy rate
        mean_sr = sum(all_sr) / len(all_sr)

        # Identify users with much higher secrecy rates than average
        for i in range(self.num_pairs):
            SR1, SR2 = rates[i][0], rates[i][1]
            RT1, RT2 = self.RT1[i], self.RT2[i]

            # Only adjust if constraint is exceeded by large margin and far above mean
            if SR1 > RT1 * 1.5 and SR1 > mean_sr * 1.3:
                # Reduce power for User 1 (will be redistributed later)
                reduction = min(powers[i][0] * 0.1, powers[i][0] * (SR1 - RT1 * 1.2) / SR1)
                powers[i][0] -= reduction

            if SR2 > RT2 * 1.5 and SR2 > mean_sr * 1.3:
                # Reduce power for User 2 (will be redistributed later)
                reduction = min(powers[i][1] * 0.1, powers[i][1] * (SR2 - RT2 * 1.2) / SR2)
                powers[i][1] -= reduction

        # Find users that need more power to meet constraints
        # and redistribute the saved power
        saved_power = self.P_total - (sum(sum(p) for p in powers[:-1]) + powers[-1][0])

        if saved_power > 0:
            # Redistribute to users not meeting constraints
            for i in range(self.num_pairs):
                SR1, SR2 = rates[i][0], rates[i][1]
                RT1, RT2 = self.RT1[i], self.RT2[i]

                deficit1 = max(0, RT1 - SR1)
                deficit2 = max(0, RT2 - SR2)

                if deficit1 > 0:
                    increase = min(saved_power, deficit1 * powers[i][0] * 0.3)
                    powers[i][0] += increase
                    saved_power -= increase

                if deficit2 > 0 and saved_power > 0:
                    increase = min(saved_power, deficit2 * powers[i][1] * 0.3)
                    powers[i][1] += increase
                    saved_power -= increase

            # If power still remains, add to artificial noise
            if saved_power > 0:
                powers[-1][0] += saved_power

        return powers

    def step(self, actions):
        """Take a step in the environment based on actions with improved constraint handling"""
        # Extract Pn from actions
        pn_contributions = [a[-1] for a in actions]
        pn_value = np.mean(pn_contributions)  # Average of all Pn contributions

        # Enforce minimum Pn constraint (adjusted to ensure it's not too small)
        min_pn = 0.05 * self.P_total  # 5% of total power for artificial noise
        pn_value = max(pn_value, min_pn)

        # Create user power allocations without Pn
        user_powers = [a[:-1] for a in actions]

        # Create final power allocation list
        all_powers = user_powers + [[pn_value]]

        # Apply power constraints (P1 <= PT1, P2 <= PT2)
        all_powers = self.apply_power_constraints(all_powers)

        # Calculate initial SINRs and rates for all pairs
        initial_rates = []
        for i in range(self.num_pairs):
            SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(i, all_powers)
            rates = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)
            initial_rates.append(rates)

        # First scaling to make sure we allocate reasonable power amounts
        scaling_factor = 4.0  # Higher initial scaling to allocate more power
        for i in range(len(all_powers) - 1):
            all_powers[i] = [p * scaling_factor for p in all_powers[i]]
        all_powers[-1] = [all_powers[-1][0] * scaling_factor]

        # Reserve power for adjustments
        remaining_power = self.P_total * 0.2  # Reserve 20% for adjustments
        power_adjustments_made = False

        # PHASE 1: First pass - Identify and fix constraint violations
        for i in range(self.num_pairs):
            SR1, SR2 = initial_rates[i][0], initial_rates[i][1]

            # Check if constraints are met
            if SR1 < self.RT1[i] or SR2 < self.RT2[i]:
                # Adjust power for this pair
                P1, P2, remaining_power, adjusted = self.adjust_power_for_constraints(
                    i, initial_rates[i], all_powers, remaining_power
                )

                if adjusted:
                    all_powers[i][0] = P1
                    all_powers[i][1] = P2
                    power_adjustments_made = True

        # PHASE 2: Second pass - Balance power within pairs
        # This is critical for cases like Pair 2 where one user exceeds while another doesn't meet constraints
        for i in range(self.num_pairs):
            # Recalculate rates after first phase adjustments
            SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(i, all_powers)
            current_rates = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)

            # Apply the balance_power_within_pair function
            P1, P2 = self.balance_power_within_pair(i, current_rates, all_powers[i], remaining_power)
            all_powers[i][0] = P1
            all_powers[i][1] = P2

        # PHASE 3: Targeted fix for Pair 2 (or any problematic pair)
        # Check specifically for Pair 2 (index 1) and address its issue
        if self.num_pairs > 1:  # Make sure we have at least 2 pairs
            SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(1, all_powers)  # Pair 2
            pair2_rates = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)
            SR1, SR2 = pair2_rates[0], pair2_rates[1]

            if SR1 < self.RT1[1] and SR2 > self.RT2[1] * 1.2:
                # Pair 2 has the specific issue you identified
                # Shift power from user 2 to user 1
                power_to_shift = min(all_powers[1][1] * 0.25, 0.8)  # Shift up to 25% of P2
                all_powers[1][0] += power_to_shift  # Add to P1
                all_powers[1][1] -= power_to_shift  # Subtract from P2
                print(f"Fixing Pair 2 imbalance: Shifted {power_to_shift:.4f}W from User 2 to User 1")

        # PHASE 4: Ensure powers don't exceed thresholds
        # Apply strict threshold enforcement before normalization
        for i in range(self.num_pairs):
            all_powers[i][0] = min(all_powers[i][0], self.PT1[i])
            all_powers[i][1] = min(all_powers[i][1], self.PT2[i])

        # PHASE 5: Balance secrecy rates across users
        # Recalculate all rates after power adjustments
        updated_rates = []
        for i in range(self.num_pairs):
            SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(i, all_powers)
            rates = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)
            updated_rates.append(rates)

        # Balance secrecy rates to avoid large disparities
        all_powers = self.balance_secrecy_rates(updated_rates, all_powers)
        #from here
        # Final check to ensure NOMA ordering principle (P1 > P2) while preserving constraints
        for i in range(self.num_pairs):
            if all_powers[i][0] <= all_powers[i][1]:
                # Before enforcing NOMA ordering, check current constraint satisfaction
                SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(i, all_powers)
                SR1, SR2, _, _, _, _ = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)

                # Store original power allocation
                original_p1 = all_powers[i][0]
                original_p2 = all_powers[i][1]

                # Try enforcing NOMA principle
                total_pair_power = original_p1 + original_p2
                new_p1 = total_pair_power * 0.6  # 60% to stronger user
                new_p2 = total_pair_power * 0.4  # 40% to weaker user

                # Temporarily apply new power allocation
                all_powers[i][0] = new_p1
                all_powers[i][1] = new_p2

                # Check if this would cause constraint violations
                SINR1_new, SINR2_new, SINR1E_new, SINR2E_new = self.calculate_sinr(i, all_powers)
                SR1_new, SR2_new, _, _, _, _ = self.calculate_rates(SINR1_new, SINR2_new, SINR1E_new, SINR2E_new)

                # If the new allocation would cause User 2 to not meet constraint, find a balanced solution
                if SR2_new < self.RT2[i] and SR2 >= self.RT2[i]:
                    print(f"NOMA enforcement for Pair {i+1} would cause constraint violation.")

                    # Try a more gradual adjustment that maintains constraint satisfaction
                    # Start with a 51-49 split and gradually increase until constraint is met
                    for split_ratio in [0.51, 0.52, 0.53, 0.54, 0.55]:
                        test_p1 = total_pair_power * split_ratio
                        test_p2 = total_pair_power * (1 - split_ratio)

                        all_powers[i][0] = test_p1
                        all_powers[i][1] = test_p2

                        test_SINR1, test_SINR2, test_SINR1E, test_SINR2E = self.calculate_sinr(i, all_powers)
                        test_SR1, test_SR2, _, _, _, _ = self.calculate_rates(test_SINR1, test_SINR2, test_SINR1E, test_SINR2E)

                        if test_SR2 >= self.RT2[i]:
                            print(f"Found balanced solution for Pair {i+1}: P1={test_p1:.4f}, P2={test_p2:.4f}, SR2={test_SR2:.4f}")
                            break

                        # If we reach the end without finding a solution, revert to original
                        if split_ratio == 0.55 and test_SR2 < self.RT2[i]:
                            all_powers[i][0] = original_p1
                            all_powers[i][1] = original_p2
                            print(f"Reverted to original for Pair {i+1} to maintain constraint satisfaction")
                else:
                    print(f"Enforcing NOMA principle for Pair {i+1}: Adjusted P1={new_p1:.4f}, P2={new_p2:.4f}")
        #until here
        # Calculate total power before normalization
        current_total_power = sum(sum(powers) for powers in all_powers[:-1]) + all_powers[-1][0]

        # Normalize to exactly meet total power constraint (20W)
        if abs(current_total_power - self.P_total) > 1e-6:
            scale_factor = self.P_total / current_total_power
            for i in range(len(all_powers)):
                if i < len(all_powers) - 1:  # User powers
                    all_powers[i] = [p * scale_factor for p in all_powers[i]]
                else:  # Noise power
                    all_powers[i] = [all_powers[i][0] * scale_factor]

        # Verify total power is exactly 20W
        total_power = sum(sum(powers) for powers in all_powers[:-1]) + all_powers[-1][0]
        print(f"Total power allocation: {total_power:.4f}W")

        # Final rate calculation and reward calculation after power adjustments
        rewards = []
        states = []
        rates = []

        total_sr = 0
        total_legitimate_rate = 0
        total_eavesdropper_rate = 0

        # Final check and adjustment to ensure power allocations don't exceed thresholds
        for i in range(self.num_pairs):
            if all_powers[i][0] > self.PT1[i] or all_powers[i][1] > self.PT2[i]:
                all_powers[i][0] = min(all_powers[i][0], self.PT1[i])
                all_powers[i][1] = min(all_powers[i][1], self.PT2[i])
                # Re-normalize after this adjustment (localized to this pair)
                pair_power = sum(all_powers[i])
                target_power = self.PT1[i] + self.PT2[i]
                if pair_power < target_power:
                    # If we're under the threshold, scale up proportionally
                    scale = target_power / pair_power
                    all_powers[i] = [p * scale for p in all_powers[i]]

        # Final rate calculation with adjusted powers
        for i in range(self.num_pairs):
            SINR1, SINR2, SINR1E, SINR2E = self.calculate_sinr(i, all_powers)
            SR1, SR2, R1, R2, R1E, R2E = self.calculate_rates(SINR1, SINR2, SINR1E, SINR2E)

            # Adjust thresholds based on whether users need more power to meet constraints
            self.adjust_thresholds_based_on_necessity([(SR1, SR2, R1, R2, R1E, R2E)], [all_powers[i], i])

            # Calculate base reward as secrecy rate sum
            reward = SR1 + SR2

            # Add reward component for maximizing the gap between legitimate and eavesdropper rates
            legitimate_rate = R1 + R2
            eavesdropper_rate = R1E + R2E
            security_gap = legitimate_rate - eavesdropper_rate
            reward += 2 * security_gap  # Give extra weight to increasing the gap

            # Reward to increase security ratio Secrecy/Legitimate
            if legitimate_rate > 0:
                reward += 2 * (security_gap / legitimate_rate)

            # Add constraint-focused reward (much higher weight for constraint satisfaction)
            constraint_reward = self.calculate_constraint_reward((SR1, SR2, R1, R2, R1E, R2E), i)
            reward += constraint_reward

            # Reward or penalize based on power allocation vs threshold
            # Reward efficient use of power
            p1_usage_ratio = all_powers[i][0] / self.PT1[i]
            p2_usage_ratio = all_powers[i][1] / self.PT2[i]

            # If user is using less than threshold but meeting constraint, reward efficiency
            if p1_usage_ratio < 0.9 and SR1 >= self.RT1[i]:
                reward += 5 * (1 - p1_usage_ratio)
            if p2_usage_ratio < 0.9 and SR2 >= self.RT2[i]:
                reward += 5 * (1 - p2_usage_ratio)

            # If user is at threshold limit but barely meeting constraint, penalize inefficiency
            if p1_usage_ratio > 0.95 and 1.0 <= (SR1 / self.RT1[i]) <= 1.1:
                reward -= 3
            if p2_usage_ratio > 0.95 and 1.0 <= (SR2 / self.RT2[i]) <= 1.1:
                reward -= 3

            # Penalize zero secrecy rate more heavily
            if SR1 == 0 or SR2 == 0:
                reward -= 15

            # Add channel-gain based power allocation reward
            H1, H2, H1e, H2e = self.channel_matrices[i]
            H1_gain = self.calculate_channel_gain(H1)  # Stronger user
            H2_gain = self.calculate_channel_gain(H2)  # Weaker user

            # Enhanced reward to encourage more power to strong user for uplink NOMA
            power_ratio = all_powers[i][0] / (all_powers[i][0] + all_powers[i][1] + 1e-10)
            gain_ratio = H1_gain / (H2_gain + 1e-10)

            # Channel-aware power allocation reward
            ideal_ratio = gain_ratio / (1 + gain_ratio)  # Transform gain ratio to power ratio

            # Reward for power allocation that matches channel conditions
            power_alignment_penalty = 5 * abs(power_ratio - ideal_ratio)
            reward -= power_alignment_penalty

            # Add rewards for effective artificial noise allocation
            pn_ratio = all_powers[-1][0] / self.P_total

            # Calculate average eavesdropper channel strength
            H1e_gain = self.calculate_channel_gain(H1e)
            H2e_gain = self.calculate_channel_gain(H2e)
            eve_strength_ratio = (H1e_gain + H2e_gain) / (H1_gain + H2_gain)

            if eve_strength_ratio > 0.3:  # Eavesdropper is relatively strong
                if pn_ratio > 0.2:  # More noise is better against strong eavesdroppers
                    reward += 5 * pn_ratio
            else:  # Eavesdropper is relatively weak
                # Reward moderate noise for weak eavesdroppers
                if 0.1 < pn_ratio < 0.2:
                    reward += 3

            total_sr += SR1 + SR2
            total_legitimate_rate += R1 + R2
            total_eavesdropper_rate += R1E + R2E
            rewards.append(reward)

            # State for each pair (extended to include power thresholds and usage)
            state = [
                H1_gain, H2_gain, H1e_gain, H2e_gain,
                all_powers[i][0]/self.P_total,  # Normalized P1
                all_powers[i][1]/self.P_total,  # Normalized P2
                all_powers[-1][0]/self.P_total,  # Global Pn
                self.PT1[i]/self.P_total,  # Normalized PT1
                self.PT2[i]/self.P_total,  # Normalized PT2
                SR1 - self.RT1[i],  # Secrecy rate gap from threshold (user 1)
                SR2 - self.RT2[i]   # Secrecy rate gap from threshold (user 2)
            ]
            states.append(state)
            rates.append((SR1, SR2, R1, R2, R1E, R2E))

        # Ensure all thresholds sum to exactly P_total after this step
        self.normalize_power_thresholds()

        # Final verification of threshold sum
        pt_sum = sum(self.PT1) + sum(self.PT2)
        print(f"Sum of all power thresholds: {pt_sum:.4f}W")

        return states, rewards, total_sr, rates, all_powers, total_legitimate_rate, total_eavesdropper_rate

    def reset(self):
        """Reset environment for new episode with improved initial allocations"""
        # Better initial power thresholds based on channel conditions
        self.PT1 = np.zeros(self.num_pairs)
        self.PT2 = np.zeros(self.num_pairs)

        # Analyze channel gains to set initial power thresholds
        for i in range(self.num_pairs):
            H1, H2, H1e, H2e = self.channel_matrices[i]
            H1_gain = self.calculate_channel_gain(H1)  # Stronger user to BS
            H2_gain = self.calculate_channel_gain(H2)  # Weaker user to BS
            H1e_gain = self.calculate_channel_gain(H1e)  # Stronger user to Eve
            H2e_gain = self.calculate_channel_gain(H2e)  # Weaker user to Eve

            # Calculate channel ratios to determine power needs
            legitimate_ratio = H1_gain / H2_gain  # How much stronger is User 1
            eve_ratio1 = H1_gain / (H1e_gain + 1e-10)  # User 1 legitimate vs eve channel
            eve_ratio2 = H2_gain / (H2e_gain + 1e-10)  # User 2 legitimate vs eve channel

            # Calculate baseline power per pair
            pair_power = self.P_total / self.num_pairs

            # Allocate more power to Pair 2 (or any pair with challenging channels)
            pair_power_boost = 1.0
            if i == 1:  # Special handling for Pair 2
                pair_power_boost = 1.2  # Give Pair 2 more power initially

            # Divide power between users based on channel conditions and rate targets
            # Higher power to user with lower eve_ratio (worse security condition)
            if eve_ratio1 < eve_ratio2:
                # User 1 has worse security condition
                self.PT1[i] = pair_power * 0.6 * pair_power_boost
                self.PT2[i] = pair_power * 0.4 * pair_power_boost
            else:
                # User 2 has worse security condition
                self.PT1[i] = pair_power * 0.5 * pair_power_boost
                self.PT2[i] = pair_power * 0.5 * pair_power_boost

            # Further adjust based on RT1 and RT2 thresholds
            # If RT1 is higher than RT2, allocate more power to User 1
            rt_ratio = self.RT1[i] / (self.RT2[i] + 1e-10)
            if rt_ratio > 2:  # RT1 is much higher than RT2
                total_power = self.PT1[i] + self.PT2[i]
                self.PT1[i] = total_power * 0.65
                self.PT2[i] = total_power * 0.35

            # Special fix for Pair 2 - allocate more power to User 1
            if i == 1:
                total_power = self.PT1[i] + self.PT2[i]
                self.PT1[i] = total_power * 0.65  # 65% to User 1
                self.PT2[i] = total_power * 0.35  # 35% to User 2

        # Ensure all thresholds sum to exactly P_total
        self.normalize_power_thresholds()

        initial_states = []
        for i in range(self.num_pairs):
            H1, H2, H1e, H2e = self.channel_matrices[i]
            H1_gain = self.calculate_channel_gain(H1)
            H2_gain = self.calculate_channel_gain(H2)
            H1e_gain = self.calculate_channel_gain(H1e)
            H2e_gain = self.calculate_channel_gain(H2e)

            # More realistic initial power allocation based on thresholds
            p1_ratio = self.PT1[i] / self.P_total
            p2_ratio = self.PT2[i] / self.P_total
            pn_ratio = 0.2  # Initial noise ratio

            initial_states.append([
                H1_gain, H2_gain, H1e_gain, H2e_gain,
                p1_ratio, p2_ratio, pn_ratio,  # Initial power allocations
                self.PT1[i]/self.P_total,  # Normalized PT1
                self.PT2[i]/self.P_total,  # Normalized PT2
                -self.RT1[i],  # Initial gap (negative because we start below threshold)
                -self.RT2[i]   # Initial gap (negative because we start below threshold)
            ])
        return initial_states


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 400)
        self.fc2 = nn.Linear(400, 300)
        self.fc3 = nn.Linear(300, action_dim + 1)  # +1 for Pn contribution

        # Initialize with different weights to encourage diversity
        self.fc3.weight.data.uniform_(-0.003, 0.003)
        self.fc3.bias.data.uniform_(-0.003, 0.003)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        raw_output = self.fc3(x)

        # Check if we're dealing with a single sample or a batch
        if raw_output.dim() == 1:
            # Single sample case - Modified to prioritize users based on constraints
            # Check state[9] (SR1 gap) and state[10] (SR2 gap)
            if state[9] < 0:  # User 1 is not meeting constraint
                # Give extra power to user 1
                p1 = torch.sigmoid(raw_output[0]) * 1.6
                p2 = torch.sigmoid(raw_output[1]) * 1.0
            elif state[10] < 0:  # User 2 is not meeting constraint
                # Give extra power to user 2
                p1 = torch.sigmoid(raw_output[0]) * 1.2
                p2 = torch.sigmoid(raw_output[1]) * 1.4
            else:
                # Both meeting constraints - allocate based on NOMA principle
                p1 = torch.sigmoid(raw_output[0]) * 1.4
                p2 = torch.sigmoid(raw_output[1]) * 1.2

            # Check if allocated power is within threshold
            pt1 = state[7] * 20  # PT1 normalized * total power
            pt2 = state[8] * 20  # PT2 normalized * total power

            # Ensure we don't exceed thresholds
            p1 = min(p1, pt1)
            p2 = min(p2, pt2)

            pn = torch.sigmoid(raw_output[2]) * 0.6

            return torch.tensor([p1, p2, pn])
        else:
            # Batch case
            # For batches, we need to individually evaluate each sample
            p1_list = []
            p2_list = []
            pn_list = []

            for i in range(raw_output.shape[0]):
                if state[i, 9] < 0:  # User 1 not meeting constraint
                    p1 = torch.sigmoid(raw_output[i, 0]) * 1.6
                    p2 = torch.sigmoid(raw_output[i, 1]) * 1.0
                elif state[i, 10] < 0:  # User 2 not meeting constraint
                    p1 = torch.sigmoid(raw_output[i, 0]) * 1.2
                    p2 = torch.sigmoid(raw_output[i, 1]) * 1.4
                else:
                    p1 = torch.sigmoid(raw_output[i, 0]) * 1.4
                    p2 = torch.sigmoid(raw_output[i, 1]) * 1.2

                # Ensure within thresholds
                pt1 = state[i, 7] * 20  # PT1
                pt2 = state[i, 8] * 20  # PT2
                p1 = min(p1, pt1)
                p2 = min(p2, pt2)

                pn = torch.sigmoid(raw_output[i, 2]) * 0.6

                p1_list.append(p1)
                p2_list.append(p2)
                pn_list.append(pn)

            return torch.stack([
                torch.tensor(p1_list),
                torch.tensor(p2_list),
                torch.tensor(pn_list)
            ], dim=1)


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, num_pairs):
        super(Critic, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim + 1  # +1 for Pn
        self.num_pairs = num_pairs

        # Total input size for all pairs combined
        self.total_input_size = (state_dim + action_dim + 1) * num_pairs

        self.fc1 = nn.Linear(self.total_input_size, 400)
        self.fc2 = nn.Linear(400, 300)
        self.fc3 = nn.Linear(300, 1)

    def forward(self, states, actions):
        # Combine states and actions
        x = torch.cat([states, actions], dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)


class MultiAgentDDPG:
    def __init__(self, num_pairs, state_dim, action_dim):
        self.num_pairs = num_pairs
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Initialize networks
        self.actors = [Actor(state_dim, action_dim).to(self.device) for _ in range(num_pairs)]
        self.actor_targets = [Actor(state_dim, action_dim).to(self.device) for _ in range(num_pairs)]

        # Initialize critic networks (shared critic for centralized training)
        self.critic = Critic(state_dim, action_dim, num_pairs).to(self.device)
        self.critic_target = Critic(state_dim, action_dim, num_pairs).to(self.device)

        # Copy initial weights
        for i in range(num_pairs):
            self.actor_targets[i].load_state_dict(self.actors[i].state_dict())
        self.critic_target.load_state_dict(self.critic.state_dict())

        # Initialize optimizers with higher learning rates
        self.actor_optimizers = [optim.Adam(self.actors[i].parameters(), lr=3e-4) for i in range(num_pairs)]
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=3e-3)

        # Replay buffer
        self.memory = deque(maxlen=100000)

        # Hyperparameters
        self.batch_size = 128  # Increased from 64
        self.gamma = 0.995  # Discount factor
        self.tau = 0.015  # Increased from 0.01 for faster target network updates

        # Exploration noise parameters with higher initial noise for better exploration
        self.noise_scale = 0.3  # Increased from 0.1
        self.noise_decay = 0.998  # Slower decay
        self.min_noise = 0.07  # Higher minimum noise level

    def select_action(self, states, add_noise=True):
        """Select actions for all agents based on current policy"""
        actions = []

        for i in range(self.num_pairs):
            state = torch.FloatTensor(states[i]).to(self.device)
            action = self.actors[i](state).cpu().detach().numpy()

            if add_noise:
                # Add exploration noise
                noise = np.random.normal(0, self.noise_scale, size=self.action_dim + 1)
                action = np.clip(action + noise, 0, 1)

            actions.append(action)

        return actions

    def remember(self, states, actions, rewards, next_states):
        """Store experience in replay buffer"""
        self.memory.append((states, actions, rewards, next_states))

    def update_noise(self):
        """Decay exploration noise"""
        self.noise_scale = max(self.min_noise, self.noise_scale * self.noise_decay)

    def update(self):
        """Update actor and critic networks"""
        if len(self.memory) < self.batch_size:
            return

        # Sample random batch from replay buffer
        batch = random.sample(self.memory, self.batch_size)

        # Extract batch data
        states_batch = [[] for _ in range(self.num_pairs)]
        actions_batch = [[] for _ in range(self.num_pairs)]
        rewards_batch = [[] for _ in range(self.num_pairs)]
        next_states_batch = [[] for _ in range(self.num_pairs)]

        for experience in batch:
            states, actions, rewards, next_states = experience

            for i in range(self.num_pairs):
                states_batch[i].append(states[i])
                actions_batch[i].append(actions[i])
                rewards_batch[i].append(rewards[i])
                next_states_batch[i].append(next_states[i])

        # Convert to tensors
        states_tensor = [torch.FloatTensor(np.array(states_batch[i])).to(self.device)
                         for i in range(self.num_pairs)]
        actions_tensor = [torch.FloatTensor(np.array(actions_batch[i])).to(self.device)
                          for i in range(self.num_pairs)]
        rewards_tensor = [torch.FloatTensor(np.array(rewards_batch[i])).to(self.device)
                          for i in range(self.num_pairs)]
        next_states_tensor = [torch.FloatTensor(np.array(next_states_batch[i])).to(self.device)
                              for i in range(self.num_pairs)]

        # Update critic
        self._update_critic(states_tensor, actions_tensor, rewards_tensor, next_states_tensor)

        # Update actors
        self._update_actors(states_tensor)

        # Update target networks
        self._update_targets()

    def _update_critic(self, states, actions, rewards, next_states):
        """Update critic network"""
        # Get next actions from target actors
        next_actions = [self.actor_targets[i](next_states[i]) for i in range(self.num_pairs)]

        # Flatten states and actions for the critic
        flat_states = torch.cat([s.flatten(1) for s in states], dim=1)
        flat_actions = torch.cat([a.flatten(1) for a in actions], dim=1)
        flat_next_states = torch.cat([s.flatten(1) for s in next_states], dim=1)
        flat_next_actions = torch.cat([a.flatten(1) for a in next_actions], dim=1)

        # Compute target Q value
        target_q = self.critic_target(flat_next_states, flat_next_actions)

        # Compute rewards (sum of all agents' rewards)
        flat_rewards = sum(rewards[i] for i in range(self.num_pairs))

        # Compute target
        target = flat_rewards + self.gamma * target_q

        # Compute current Q
        current_q = self.critic(flat_states, flat_actions)

        # Compute critic loss
        critic_loss = F.mse_loss(current_q, target.detach())

        # Update critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

    def _update_actors(self, states):
        """Update actor networks"""
        for i in range(self.num_pairs):
            # Get current actions
            curr_actions = [self.actors[j](states[j]) if j == i
                           else self.actors[j](states[j]).detach()
                           for j in range(self.num_pairs)]

            # Flatten states and actions for critic
            flat_states = torch.cat([s.flatten(1) for s in states], dim=1)
            flat_actions = torch.cat([a.flatten(1) for a in curr_actions], dim=1)

            # Compute actor loss (negative of Q value)
            actor_loss = -self.critic(flat_states, flat_actions).mean()

            # Update actor
            self.actor_optimizers[i].zero_grad()
            actor_loss.backward()
            self.actor_optimizers[i].step()

    def _update_targets(self):
        """Soft update target networks"""
        # Update critic target
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

        # Update actor targets
        for i in range(self.num_pairs):
            for param, target_param in zip(self.actors[i].parameters(), self.actor_targets[i].parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save_models(self, path):
        """Save all models to disk"""
        torch.save(self.critic.state_dict(), f"{path}/critic.pt")
        torch.save(self.critic_target.state_dict(), f"{path}/critic_target.pt")

        for i in range(self.num_pairs):
            torch.save(self.actors[i].state_dict(), f"{path}/actor_{i}.pt")
            torch.save(self.actor_targets[i].state_dict(), f"{path}/actor_target_{i}.pt")

    def load_models(self, path):
        """Load all models from disk"""
        self.critic.load_state_dict(torch.load(f"{path}/critic.pt"))
        self.critic_target.load_state_dict(torch.load(f"{path}/critic_target.pt"))

        for i in range(self.num_pairs):
            self.actors[i].load_state_dict(torch.load(f"{path}/actor_{i}.pt"))
            self.actor_targets[i].load_state_dict(torch.load(f"{path}/actor_target_{i}.pt"))


def train(num_episodes=1000):
    # Environment parameters
    num_pairs = 3
    P_total = 20  # Total power constraint of 20W
    min_power_ratio = 0.1
    noise_power = 1e-6
    eavesdropper_scale = 0.5
    alpha = 0.5
    mimo_dim = 2

    # Create environment
    env = NomaEnvironment(num_pairs, P_total, min_power_ratio, noise_power, eavesdropper_scale, alpha, mimo_dim)

    # DDPG parameters
    state_dim = 11  # Based on state definition in env.step()
    action_dim = 2  # P1, P2 (Pn will be added in the Actor output)

    # Initialize MADDPG agent
    agent = MultiAgentDDPG(num_pairs, state_dim, action_dim)

    # Track metrics
    rewards_history = []
    secrecy_rate_history = []
    legitimate_rate_history = []
    eavesdropper_rate_history = []
    power_history = []  # Track total power allocation
    constraint_satisfaction_history = []  # Track constraint satisfaction
    threshold_sum_history = []  # Track sum of power thresholds

    # Track best episode
    best_reward = float('-inf')
    best_episode_data = None

    # Create models directory if it doesn't exist
    import os
    if not os.path.exists("./models"):
        os.makedirs("./models")

    for episode in range(num_episodes):
        # Reset environment
        states = env.reset()

        # Select action according to current policy
        actions = agent.select_action(states, add_noise=True)

        # Take action in environment
        next_states, rewards, total_sr, rates, powers, total_legitimate_rate, total_eavesdropper_rate = env.step(actions)

        # Store experience in replay buffer
        agent.remember(states, actions, rewards, next_states)

        # Update networks
        agent.update()

        # Update exploration noise
        agent.update_noise()

        # Record metrics
        episode_reward = sum(rewards)
        rewards_history.append(episode_reward)
        secrecy_rate_history.append(total_sr)
        legitimate_rate_history.append(total_legitimate_rate)
        eavesdropper_rate_history.append(total_eavesdropper_rate)

        # Calculate and record total power allocation
        total_power = sum(sum(p) for p in powers[:-1]) + powers[-1][0]
        power_history.append(total_power)

        # Record threshold sum
        threshold_sum = sum(env.PT1) + sum(env.PT2)
        threshold_sum_history.append(threshold_sum)

        # Calculate constraint satisfaction rate
        constraints_met = 0
        total_constraints = 2 * num_pairs  # SR1 and SR2 for each pair
        for i in range(num_pairs):
            sr1, sr2 = rates[i][0], rates[i][1]
            rt1, rt2 = env.RT1[i], env.RT2[i]
            if sr1 >= rt1:
                constraints_met += 1
            if sr2 >= rt2:
                constraints_met += 1

        constraint_satisfaction = constraints_met / total_constraints
        constraint_satisfaction_history.append(constraint_satisfaction)

        # Check if this is the best episode - prioritize constraint satisfaction with good reward
        episode_score = episode_reward * (1 + constraint_satisfaction)

        # Only consider episodes with 100% constraint satisfaction for best episode
        if constraint_satisfaction == 1.0 and episode_score > best_reward:
            best_reward = episode_score
            best_episode_data = {
                'episode': episode + 1,
                'total_reward': episode_reward,
                'secrecy_rate': total_sr,
                'legitimate_rate': total_legitimate_rate,
                'eavesdropper_rate': total_eavesdropper_rate,
                'secrecy_ratio': total_sr / (total_legitimate_rate + 1e-6),
                'powers': powers,
                'rates': rates,
                'PT1': env.PT1.copy(),
                'PT2': env.PT2.copy(),
                'RT1': env.RT1.copy(),
                'RT2': env.RT2.copy(),
                'total_power': total_power,
                'constraint_satisfaction': constraint_satisfaction,
                'threshold_sum': threshold_sum
            }

        # Print progress
        if (episode + 1) % 10 == 0:
            print(f"Episode: {episode+1}, Total Reward: {episode_reward:.2f}, Total SR: {total_sr:.2f}")
            print(f"Legitimate Rate: {total_legitimate_rate:.2f}, Eavesdropper Rate: {total_eavesdropper_rate:.2f}")
            print(f"Total Power: {total_power:.4f}W, Constraint Satisfaction: {constraint_satisfaction*100:.1f}%")
            print(f"Sum of Power Thresholds: {threshold_sum:.4f}W")

            # Print per-pair results every 100 episodes
            if (episode + 1) % 100 == 0:
                print("\n===== Current Power Allocations =====")
                for i in range(num_pairs):
                    print(f"Pair {i+1}:")
                    print(f"P1: {powers[i][0]:.4f} / PT1: {env.PT1[i]:.4f}")
                    print(f"P2: {powers[i][1]:.4f} / PT2: {env.PT2[i]:.4f}")
                print(f"Pn: {powers[-1][0]:.4f}")

                print("\n===== Current Secrecy Rate Status =====")
                for i in range(num_pairs):
                    sr1, sr2 = rates[i][0], rates[i][1]
                    rt1, rt2 = env.RT1[i], env.RT2[i]
                    print(f"Pair {i+1}:")
                    print(f"SR1: {sr1:.4f} (Target: {rt1:.4f}) - {'Met' if sr1 >= rt1 else 'Not Met'}")
                    print(f"SR2: {sr2:.4f} (Target: {rt2:.4f}) - {'Met' if sr2 >= rt2 else 'Not Met'}")

            print("---")

        # Save model periodically
        if (episode + 1) % 100 == 0:
            episode_dir = f"./models/episode_{episode+1}"
            if not os.path.exists(episode_dir):
                os.makedirs(episode_dir)
            agent.save_models(episode_dir)

    # Print best episode results in the specified format
    if best_episode_data:
        print("\nBest Reward Results =====")
        print(f"Secrecy Rate: {best_episode_data['secrecy_rate']:.4f}")
        print(f"Total Legitimate Rate: {best_episode_data['legitimate_rate']:.4f}")
        print(f"Total Eavesdropper Rate: {best_episode_data['eavesdropper_rate']:.4f}")
        print(f"Secrecy Ratio (Secrecy/Legitimate): {best_episode_data['secrecy_ratio']:.4f}")
        print(f"Total Power: {best_episode_data['total_power']:.4f}W")
        print(f"Sum of All Power Thresholds: {best_episode_data['threshold_sum']:.4f}W")
        print(f"Constraint Satisfaction: {best_episode_data['constraint_satisfaction']*100:.1f}%")

        print("\n===== Power Allocations =====")
        for i in range(num_pairs):
            print(f"Pair {i+1}:")
            print(f"P1: {best_episode_data['powers'][i][0]:.4f} / PT1: {best_episode_data['PT1'][i]:.4f}")
            print(f"P2: {best_episode_data['powers'][i][1]:.4f} / PT2: {best_episode_data['PT2'][i]:.4f}")
        print(f"Pn: {best_episode_data['powers'][-1][0]:.4f}")

        print("\n===== Secrecy Rate Constraints =====")
        for i in range(num_pairs):
            sr1, sr2 = best_episode_data['rates'][i][0], best_episode_data['rates'][i][1]
            rt1, rt2 = best_episode_data['RT1'][i], best_episode_data['RT2'][i]

            print(f"Pair {i+1}:")
            print(f"SR1: {sr1:.4f} (Target: {rt1:.4f}) - {'Met' if sr1 >= rt1 else 'Not Met'}")
            print(f"SR2: {sr2:.4f} (Target: {rt2:.4f}) - {'Met' if sr2 >= rt2 else 'Not Met'}")

    # Plot training curves
    plt.figure(figsize=(16, 12))

    plt.subplot(3, 2, 1)
    plt.plot(rewards_history)
    plt.title("Total Rewards")
    plt.xlabel("Episode")
    plt.ylabel("Reward")

    plt.subplot(3, 2, 2)
    plt.plot(secrecy_rate_history)
    plt.title("Total Secrecy Rate")
    plt.xlabel("Episode")
    plt.ylabel("Secrecy Rate")

    plt.subplot(3, 2, 3)
    plt.plot(legitimate_rate_history, label="Legitimate")
    plt.plot(eavesdropper_rate_history, label="Eavesdropper")
    plt.title("Legitimate vs Eavesdropper Rate")
    plt.xlabel("Episode")
    plt.ylabel("Rate")
    plt.legend()

    plt.subplot(3, 2, 4)
    secure_ratio = [s/(l+1e-6) for s, l in zip(secrecy_rate_history, legitimate_rate_history)]
    plt.plot(secure_ratio)
    plt.title("Secrecy Ratio (SR/Legitimate)")
    plt.xlabel("Episode")
    plt.ylabel("Ratio")

    plt.subplot(3, 2, 5)
    plt.plot(power_history)
    plt.axhline(y=P_total, color='r', linestyle='--')
    plt.title("Total Power Allocation")
    plt.xlabel("Episode")
    plt.ylabel("Power (W)")

    plt.subplot(3, 2, 6)
    plt.plot(constraint_satisfaction_history)
    plt.plot(np.array(threshold_sum_history) / P_total, label="PT Sum / P_total")
    plt.title("Constraint Satisfaction & PT Sum Ratio")
    plt.xlabel("Episode")
    plt.ylabel("Ratio")
    plt.legend()
    plt.ylim(0, 1.05)

    plt.tight_layout()
    plt.savefig("training_curves.png")
    plt.show()

    return agent, env, rewards_history, secrecy_rate_history, best_episode_data

def plot_simple_learning_curve(rewards):
    """
    Creates a simple learning curve visualization showing convergence,
    learning efficiency, and stability.

    Args:
        rewards_history: List of episode rewards from training
    """
    import numpy as np
    import matplotlib.pyplot as plt

    # Calculate moving average for smoothing (shows convergence trend)
    window_size = 20
    smoothed_rewards = []
    for i in range(len(rewards)):
        start_idx = max(0, i - window_size)
        smoothed_rewards.append(np.mean(rewards[start_idx:i+1]))

    # Calculate moving standard deviation (shows stability)
    stability = []
    for i in range(len(rewards)):
        start_idx = max(0, i - window_size)
        stability.append(np.std(rewards[start_idx:i+1]))

    # Find the steepest improvement section (shows learning efficiency)
    smoothed_gradient = np.gradient(smoothed_rewards)
    max_gradient_idx = np.argmax(smoothed_gradient[10:]) + 10  # Skip first few episodes

    # Create the figure
    plt.figure(figsize=(10, 6))

    # Plot raw rewards and smoothed trend
    plt.plot(rewards, 'lightgray', alpha=0.5, label='Episode Rewards')
    plt.plot(smoothed_rewards, 'blue', linewidth=2, label='Trend (Moving Avg)')

    # Add stability information
    plt.fill_between(
        range(len(smoothed_rewards)),
        np.array(smoothed_rewards) - np.array(stability),
        np.array(smoothed_rewards) + np.array(stability),
        color='blue', alpha=0.2, label='Stability (±1 Std Dev)'
    )

    # Highlight the fastest learning section
    plt.axvspan(max_gradient_idx-5, max_gradient_idx+5, color='green', alpha=0.3,
                label='Fastest Learning')

    # Add annotations
    plt.title('NOMA Security Optimization Learning Curve', fontsize=14)
    plt.xlabel('Episode', fontsize=12)
    plt.ylabel('Reward', fontsize=12)
    plt.grid(alpha=0.3)
    plt.legend()

    # Add text explaining what to look for
    plt.figtext(0.02, 0.02,
                "• Convergence: Observe if the blue line levels off\n"
                "• Learning Efficiency: Green area shows fastest improvement\n"
                "• Stability: Narrower blue band indicates more stable performance",
                fontsize=8, bbox=dict(facecolor='white', alpha=0.8))

    plt.tight_layout()
    plt.savefig('noma_learning_curve.png', dpi=300)
    plt.show()

# After running your training function, call this:
#plot_simple_learning_curve(rewards_history)


# Run training
if __name__ == "__main__":
    agent, env, rewards, secrecy_rates, best_results = train(num_episodes=1000)
    plot_simple_learning_curve(rewards)
    print("Training completed!")
# Out:
# ===== Channel Gains =====
# Pair 1:
# h1: 2.4923
# h2: 1.3408
# h1e: 2.5273
# h2e: 0.6687
# Pair 2:
# h1: 1.0855
# h2: 0.9357
# h1e: 1.5062
# h2e: 1.8596
# Pair 3:
# h1: 4.1092
# h2: 2.0069
# h1e: 2.0892
# h2e: 1.0248
# Pair 2: Transferred 0.4357W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3781W from User 2 to User 1
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7956, P2=1.7252, SR2=0.3017
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.5753W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3452W from User 2 to User 1
# Pair 3: Transferred 0.5207W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=1.5200, P2=1.0133
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7158W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5435W from User 1 to User 2
# Pair 2: Transferred 0.4834W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.5000W from User 2 to User 1
# Pair 3: Transferred 0.7895W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6096W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3657W from User 2 to User 1
# Pair 3: Transferred 0.6301W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6492W from User 1 to User 2
# Pair 3: Transferred 0.7413W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5695W from User 1 to User 2
# Pair 2: Transferred 0.7422W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4453W from User 2 to User 1
# Pair 3: Transferred 0.7538W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6879W from User 2 to User 1
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.5905W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.4524, P2=1.6350
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 10, Total Reward: 430.89, Total SR: 6.65
# Legitimate Rate: 8.64, Eavesdropper Rate: 1.99
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.7526W from User 1 to User 2
# Pair 2: Transferred 0.4599W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2759W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.3352W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3594W from User 2 to User 1
# Pair 3: Transferred 0.3730W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.5829, P2=1.5208, SR2=0.3031
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4021W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.6564, P2=1.5915, SR2=0.3324
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7633W from User 1 to User 2
# Pair 2: Transferred 0.7455W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4473W from User 2 to User 1
# Pair 3: Transferred 0.3907W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.4833, P2=1.4251, SR2=0.3785
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7378W from User 1 to User 2
# Pair 2: Transferred 0.3680W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4021W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5667W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3400W from User 2 to User 1
# Pair 3: Transferred 0.5182W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.3239, P2=1.5493
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 3: Transferred 0.3098W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5560, P2=1.7040
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 20, Total Reward: 396.66, Total SR: 6.01
# Legitimate Rate: 8.86, Eavesdropper Rate: 2.85
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.7856W from User 1 to User 2
# Pair 2: Transferred 0.4124W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2475W from User 2 to User 1
# Pair 3: Transferred 0.6337W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.6494W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3896W from User 2 to User 1
# Pair 3: Transferred 0.5195W from User 1 to User 2
# Fixing Pair 2 imbalance: Shifted 0.5520W from User 2 to User 1
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.4806W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2884W from User 2 to User 1
# Pair 3: Transferred 0.5976W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7565W from User 1 to User 2
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.8000W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4800W from User 2 to User 1
# Pair 3: Transferred 0.4433W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.2667W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.1600W from User 2 to User 1
# Pair 3: Transferred 0.7719W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.5793W from User 1 to User 2
# Pair 3: Transferred 0.6330W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6349W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5343, P2=1.6896
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4834W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.5000W from User 2 to User 1
# Pair 3: Transferred 0.4965W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 30, Total Reward: 411.91, Total SR: 6.39
# Legitimate Rate: 8.98, Eavesdropper Rate: 2.59
# Total Power: 21.0760W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.5842W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6724W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6993W from User 1 to User 2
# Pair 2: Transferred 0.7519W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7606W from User 1 to User 2
# Pair 3: Transferred 0.7298W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.7347W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 3: Transferred 0.6391W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7753W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.3778W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2267W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.5798W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5979, P2=1.7319
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 40, Total Reward: 419.63, Total SR: 6.50
# Legitimate Rate: 8.81, Eavesdropper Rate: 2.32
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.6891W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.3865W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8252, P2=1.7537, SR2=0.3240
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.3485W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2091W from User 2 to User 1
# Pair 3: Transferred 0.7772W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4996W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2998W from User 2 to User 1
# Pair 3: Transferred 0.7041W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5159W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3096W from User 2 to User 1
# Pair 3: Transferred 0.4930W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5612W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3367W from User 2 to User 1
# Pair 3: Transferred 0.7655W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5537W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3322W from User 2 to User 1
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5731, P2=1.7154
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8145, P2=1.7434, SR2=0.3123
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 50, Total Reward: 518.41, Total SR: 6.76
# Legitimate Rate: 8.79, Eavesdropper Rate: 2.02
# Total Power: 20.0000W, Constraint Satisfaction: 100.0%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.6447W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6434W from User 1 to User 2
# Pair 2: Transferred 0.6673W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4004W from User 2 to User 1
# Pair 3: Transferred 0.7761W from User 1 to User 2
# Fixing Pair 2 imbalance: Shifted 0.5672W from User 2 to User 1
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7768W from User 1 to User 2
# Pair 3: Transferred 0.6259W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5501W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3542W from User 2 to User 1
# Pair 3: Transferred 0.5895W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4736W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2842W from User 2 to User 1
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7956, P2=1.7252, SR2=0.3171
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5403W from User 1 to User 2
# Pair 3: Transferred 0.4446W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7706, P2=1.7012, SR2=0.3484
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.2667W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.1600W from User 2 to User 1
# Pair 3: Transferred 0.5585W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.0680, P2=1.9869, SR2=0.3422
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6214W from User 1 to User 2
# Pair 2: Transferred 0.5506W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3304W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6344W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3807W from User 2 to User 1
# Pair 3: Transferred 0.5428W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 60, Total Reward: 406.98, Total SR: 6.29
# Legitimate Rate: 9.01, Eavesdropper Rate: 2.72
# Total Power: 21.0760W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4361W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2617W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.4732, P2=1.6488
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6781W from User 1 to User 2
# Pair 2: Transferred 0.6248W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3749W from User 2 to User 1
# Pair 3: Transferred 0.4941W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6122W from User 1 to User 2
# Pair 3: Transferred 0.6591W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4775W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4046W from User 2 to User 1
# Pair 3: Transferred 0.6936W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4607W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8132, P2=1.7421, SR2=0.3266
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6664W from User 1 to User 2
# Pair 3: Transferred 0.3830W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.6081, P2=1.5450, SR2=0.3248
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6713W from User 1 to User 2
# Pair 3: Transferred 0.7559W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.3684W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2211W from User 2 to User 1
# Pair 3: Transferred 0.5721W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.1030, P2=2.0206, SR2=0.3160
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7737W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7278W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 70, Total Reward: 443.60, Total SR: 6.50
# Legitimate Rate: 8.76, Eavesdropper Rate: 2.27
# Total Power: 21.3491W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.7998W from User 1 to User 2
# Pair 3: Transferred 0.4122W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6360W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5735, P2=1.7156
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5355W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3213W from User 2 to User 1
# Pair 3: Transferred 0.5197W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=1.8436, P2=1.2291
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.9680, P2=1.8908, SR2=0.3276
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5006W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.0474, P2=1.9671, SR2=0.3208
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.7196W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5822W from User 1 to User 2
# Pair 2: Transferred 0.8000W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4800W from User 2 to User 1
# Pair 3: Transferred 0.3532W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.4443W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4880W from User 2 to User 1
# Pair 3: Transferred 0.5216W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.4392, P2=1.6261
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4063W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4470W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 80, Total Reward: 293.42, Total SR: 5.73
# Legitimate Rate: 8.91, Eavesdropper Rate: 3.17
# Total Power: 20.0000W, Constraint Satisfaction: 66.7%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.6970W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4907W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2944W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7763W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6095, P2=1.7397
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5019W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6057W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4257W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4382W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2629W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4824W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3781W from User 2 to User 1
# Pair 3: Transferred 0.3815W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.6750, P2=1.6093, SR2=0.3001
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4404W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7876, P2=1.7175, SR2=0.3489
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 90, Total Reward: 516.62, Total SR: 7.16
# Legitimate Rate: 8.62, Eavesdropper Rate: 1.46
# Total Power: 20.0000W, Constraint Satisfaction: 100.0%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.6132W from User 1 to User 2
# Pair 2: Transferred 0.5214W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3129W from User 2 to User 1
# Pair 3: Transferred 0.4657W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8265, P2=1.7548, SR2=0.3113
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5501W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3301W from User 2 to User 1
# Pair 3: Transferred 0.4206W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5220W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.0219, P2=1.3479
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.0913, P2=2.0093, SR2=0.3274
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4343W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2606W from User 2 to User 1
# Pair 3: Transferred 0.7548W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.5648W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3443W from User 2 to User 1
# Pair 3: Transferred 0.6006W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5436W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5119, P2=1.6746
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7164W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8142, P2=1.7430, SR2=0.3383
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.3299W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.8000W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4800W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5837W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 100, Total Reward: 449.89, Total SR: 6.45
# Legitimate Rate: 8.55, Eavesdropper Rate: 2.10
# Total Power: 21.9050W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
#
# ===== Current Power Allocations =====
# Pair 1:
# P1: 2.7431 / PT1: 4.2220
# P2: 2.1875 / PT2: 2.8057
# Pair 2:
# P1: 2.7971 / PT1: 4.1392
# P2: 1.4289 / PT2: 2.1145
# Pair 3:
# P1: 3.0622 / PT1: 3.9131
# P2: 3.1878 / PT2: 2.8057
# Pn: 6.4984
#
# ===== Current Secrecy Rate Status =====
# Pair 1:
# SR1: 1.9167 (Target: 1.0000) - Met
# SR2: 0.4314 (Target: 0.3000) - Met
# Pair 2:
# SR1: 1.4586 (Target: 1.0000) - Met
# SR2: 0.5607 (Target: 0.3000) - Met
# Pair 3:
# SR1: 1.8223 (Target: 1.0000) - Met
# SR2: 0.2623 (Target: 0.3000) - Not Met
# ---
# Pair 1: Transferred 0.7924W from User 1 to User 2
# Pair 2: Transferred 0.5078W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3047W from User 2 to User 1
# Pair 3: Transferred 0.7848W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.2920, P2=1.2413, SR2=0.3444
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6620W from User 1 to User 2
# Pair 3: Transferred 0.4161W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4029W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2417W from User 2 to User 1
# Pair 3: Transferred 0.4014W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8526, P2=1.7799, SR2=0.3101
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4424W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4376W from User 2 to User 1
# Pair 3: Transferred 0.4565W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7622W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4573W from User 2 to User 1
# Pair 3: Transferred 0.6113W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.3881W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=1.9309, P2=1.2873
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8283, P2=1.7566, SR2=0.3350
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7318W from User 1 to User 2
# Pair 2: Transferred 0.5519W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4030W from User 2 to User 1
# Pair 3: Transferred 0.7463W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6297W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 3: Transferred 0.5132W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 110, Total Reward: 437.45, Total SR: 6.06
# Legitimate Rate: 8.57, Eavesdropper Rate: 2.51
# Total Power: 22.1851W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4834W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.5000W from User 2 to User 1
# Pair 3: Transferred 0.5779W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5608, P2=1.7072
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5561W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3337W from User 2 to User 1
# Pair 3: Transferred 0.3860W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6112, P2=1.7408
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6509W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3905W from User 2 to User 1
# Pair 3: Transferred 0.5765W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5901, P2=1.7267
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5635W from User 1 to User 2
# Pair 2: Transferred 0.7330W from User 1 to User 2
# Pair 3: Transferred 0.4643W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8230, P2=1.7515, SR2=0.3322
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7345W from User 1 to User 2
# Pair 2: Transferred 0.5871W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3554W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.8000W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4800W from User 2 to User 1
# Pair 3: Transferred 0.6562W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5547, P2=1.7031
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4242W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2545W from User 2 to User 1
# Pair 3: Transferred 0.6904W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.1125, P2=1.4083
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7369W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4421W from User 2 to User 1
# Pair 3: Transferred 0.3480W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.4899, P2=1.6599
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.3344W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2007W from User 2 to User 1
# Pair 3: Transferred 0.7347W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5824W from User 1 to User 2
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.7510W from User 2 to User 1
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 120, Total Reward: 440.72, Total SR: 6.18
# Legitimate Rate: 8.31, Eavesdropper Rate: 2.13
# Total Power: 22.0853W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.7518W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4511W from User 2 to User 1
# Pair 3: Transferred 0.7407W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5414W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3249W from User 2 to User 1
# Pair 3: Transferred 0.6017W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7218W from User 1 to User 2
# Pair 2: Transferred 0.5606W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4015W from User 2 to User 1
# Pair 3: Transferred 0.4826W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.4965, P2=1.6643
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6031W from User 1 to User 2
# Pair 2: Transferred 0.5720W from User 1 to User 2
# Pair 3: Transferred 0.5694W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6521W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5690W from User 1 to User 2
# Pair 2: Transferred 0.6580W from User 1 to User 2
# Pair 3: Transferred 0.7230W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.6841W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.0685, P2=1.3790
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# <ipython-input-1-820fc1a94df3>:1123: UserWarning: Using a target size (torch.Size([128, 128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   critic_loss = F.mse_loss(current_q, target.detach())
# Pair 2: Transferred 0.7615W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4276W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 130, Total Reward: 514.90, Total SR: 6.23
# Legitimate Rate: 8.48, Eavesdropper Rate: 2.25
# Total Power: 20.0000W, Constraint Satisfaction: 100.0%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.4863W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.0176, P2=1.9385, SR2=0.3192
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.5487W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3292W from User 2 to User 1
# Pair 3: Transferred 0.4333W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7485, P2=1.6800, SR2=0.3004
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4566W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2740W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6785W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4680W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2808W from User 2 to User 1
# Pair 3: Transferred 0.5583W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7518W from User 1 to User 2
# Pair 2: Transferred 0.3414W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3678W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7864W from User 1 to User 2
# Pair 2: Transferred 0.4522W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2713W from User 2 to User 1
# Pair 3: Transferred 0.7633W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4173W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5999W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3599W from User 2 to User 1
# Pair 3: Transferred 0.5840W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 140, Total Reward: 442.17, Total SR: 6.30
# Legitimate Rate: 8.42, Eavesdropper Rate: 2.13
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4270W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.4017W from User 2 to User 1
# Pair 3: Transferred 0.6982W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5835, P2=1.7224
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5395W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3237W from User 2 to User 1
# Pair 3: Transferred 0.7187W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.3931, P2=1.5954
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6862W from User 2 to User 1
# Pair 3: Transferred 0.3052W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=2.5373, P2=1.6916
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.1576, P2=2.0730, SR2=0.3261
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.7522W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.4319W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2591W from User 2 to User 1
# Pair 3: Transferred 0.5107W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4372W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.9183, P2=1.8431, SR2=0.3103
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4926W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2956W from User 2 to User 1
# Pair 3: Transferred 0.5601W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.1685, P2=2.0834, SR2=0.3027
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6317W from User 1 to User 2
# Pair 2: Transferred 0.4381W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2629W from User 2 to User 1
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.3130, P2=1.2615, SR2=0.3919
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5208W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3125W from User 2 to User 1
# Pair 3: Transferred 0.5851W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 150, Total Reward: 429.12, Total SR: 6.18
# Legitimate Rate: 8.66, Eavesdropper Rate: 2.48
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4298W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2579W from User 2 to User 1
# Pair 3: Transferred 0.6677W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6018W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3611W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4338W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2603W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5322W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3193W from User 2 to User 1
# Pair 3: Transferred 0.6099W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6016W from User 1 to User 2
# Pair 3: Transferred 0.7207W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.6006W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3604W from User 2 to User 1
# Pair 3: Transferred 0.6208W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5221W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.0915, P2=2.0095, SR2=0.3177
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7008W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5023W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3014W from User 2 to User 1
# Pair 3: Transferred 0.7745W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.2920, P2=1.2413, SR2=0.3632
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 160, Total Reward: 515.23, Total SR: 6.77
# Legitimate Rate: 8.64, Eavesdropper Rate: 1.87
# Total Power: 20.0000W, Constraint Satisfaction: 100.0%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.6854W from User 1 to User 2
# Pair 3: Transferred 0.5887W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.2259, P2=2.1386, SR2=0.3171
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4465W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.7757, P2=1.7060, SR2=0.3521
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6382W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3829W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.4076W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=1.8640, P2=1.7909, SR2=0.3511
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.6795W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5027W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3016W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7532W from User 1 to User 2
# Pair 3: Transferred 0.5297W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.8000W from User 1 to User 2
# Pair 2: Transferred 0.6546W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3928W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5400W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3953W from User 2 to User 1
# Pair 3: Transferred 0.6736W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4297W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2578W from User 2 to User 1
# Pair 3: Transferred 0.5925W from User 1 to User 2
# Enforcing NOMA principle for Pair 1: Adjusted P1=1.9065, P2=1.2710
# NOMA enforcement for Pair 3 would cause constraint violation.
# Found balanced solution for Pair 3: P1=2.2335, P2=2.1459, SR2=0.3170
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 170, Total Reward: 532.00, Total SR: 7.22
# Legitimate Rate: 8.77, Eavesdropper Rate: 1.55
# Total Power: 20.0000W, Constraint Satisfaction: 100.0%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4903W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3136W from User 2 to User 1
# Pair 3: Transferred 0.8000W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.7769W from User 1 to User 2
# Pair 3: Transferred 0.5255W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.6810W from User 1 to User 2
# ...
# Pair 3: Transferred 0.5622W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6470W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6845W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5496W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 930, Total Reward: 455.75, Total SR: 6.41
# Legitimate Rate: 8.51, Eavesdropper Rate: 2.10
# Total Power: 22.0396W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 1: Transferred 0.7212W from User 1 to User 2
# Pair 3: Transferred 0.6336W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6713W from User 1 to User 2
# Pair 3: Transferred 0.6257W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.7052, P2=1.8035
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6056W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6583, P2=1.7722
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5976W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6398, P2=1.7598
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5594W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.5495, P2=1.6997
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7232W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6437W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6462W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7406W from User 1 to User 2
# Pair 3: Transferred 0.6373W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6167W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6842, P2=1.7895
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 940, Total Reward: 419.31, Total SR: 6.73
# Legitimate Rate: 9.00, Eavesdropper Rate: 2.27
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.6299W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6743W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5886W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4526W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2715W from User 2 to User 1
# Pair 3: Transferred 0.6756W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6989W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6126W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6748, P2=1.7832
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6869W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6573W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6572W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7622W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 950, Total Reward: 418.55, Total SR: 6.11
# Legitimate Rate: 8.70, Eavesdropper Rate: 2.59
# Total Power: 21.2188W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 2: Transferred 0.4819W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2891W from User 2 to User 1
# Pair 3: Transferred 0.6552W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7184W from User 1 to User 2
# Pair 2: Transferred 0.5141W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3084W from User 2 to User 1
# Pair 3: Transferred 0.5927W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6281, P2=1.7521
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6085W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6689W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6937W from User 1 to User 2
# Pair 3: Transferred 0.6440W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6264W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.7069, P2=1.8046
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6328W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7210W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6878W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4814W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2889W from User 2 to User 1
# Pair 3: Transferred 0.5861W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 960, Total Reward: 430.11, Total SR: 6.43
# Legitimate Rate: 8.82, Eavesdropper Rate: 2.39
# Total Power: 21.8954W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.7085W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6981W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7139W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6589W from User 1 to User 2
# Pair 3: Transferred 0.6295W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6986W from User 1 to User 2
# Pair 3: Transferred 0.6489W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6729W from User 1 to User 2
# Pair 3: Transferred 0.6140W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6780, P2=1.7853
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7154W from User 1 to User 2
# Pair 3: Transferred 0.5912W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6245, P2=1.7497
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5619W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.7446W from User 1 to User 2
# Pair 3: Transferred 0.6664W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6277W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 970, Total Reward: 430.34, Total SR: 6.11
# Legitimate Rate: 8.50, Eavesdropper Rate: 2.38
# Total Power: 21.7333W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.6208W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6940, P2=1.7960
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5321W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6340W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6772W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7445W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4783W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2870W from User 2 to User 1
# Pair 3: Transferred 0.6920W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5575W from User 1 to User 2
# Pair 3: Transferred 0.7087W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6510W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.7037W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4830W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2898W from User 2 to User 1
# Pair 3: Transferred 0.6361W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 980, Total Reward: 419.75, Total SR: 6.24
# Legitimate Rate: 8.81, Eavesdropper Rate: 2.58
# Total Power: 21.7007W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.7307W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5813W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6633W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5914W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5492W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.5935W from User 1 to User 2
# Pair 3: Transferred 0.6218W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6963, P2=1.7975
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6337W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5593W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.4121W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2473W from User 2 to User 1
# Pair 3: Transferred 0.6529W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6954W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 990, Total Reward: 408.77, Total SR: 5.95
# Legitimate Rate: 8.79, Eavesdropper Rate: 2.84
# Total Power: 21.4728W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
# ---
# Pair 3: Transferred 0.6227W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6984, P2=1.7989
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6891W from User 1 to User 2
# Pair 2: Transferred 0.4918W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.2951W from User 2 to User 1
# Pair 3: Transferred 0.7357W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6104W from User 1 to User 2
# Pair 3: Transferred 0.6112W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6716, P2=1.7811
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6578W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 2: Transferred 0.5069W from User 2 to User 1
# Pair 2 Special Fix: Extra 0.3041W from User 2 to User 1
# Pair 3: Transferred 0.6600W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6592W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 1: Transferred 0.6432W from User 1 to User 2
# Pair 3: Transferred 0.5552W from User 1 to User 2
# NOMA enforcement for Pair 3 would cause constraint violation.
# Reverted to original for Pair 3 to maintain constraint satisfaction
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6437W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.6754W from User 1 to User 2
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Pair 3: Transferred 0.5906W from User 1 to User 2
# Enforcing NOMA principle for Pair 3: Adjusted P1=2.6232, P2=1.7488
# Total power allocation: 20.0000W
# Sum of all power thresholds: 20.0000W
# Episode: 1000, Total Reward: 412.17, Total SR: 6.66
# Legitimate Rate: 9.12, Eavesdropper Rate: 2.46
# Total Power: 20.0000W, Constraint Satisfaction: 83.3%
# Sum of Power Thresholds: 20.0000W
#
# ===== Current Power Allocations =====
# Pair 1:
# P1: 3.1546 / PT1: 4.4072
# P2: 1.9847 / PT2: 2.3731
# Pair 2:
# P1: 3.6439 / PT1: 5.2886
# P2: 1.7198 / PT2: 2.2389
# Pair 3:
# P1: 2.6232 / PT1: 3.3191
# P2: 1.7488 / PT2: 2.3731
# Pn: 5.1250
#
# ===== Current Secrecy Rate Status =====
# Pair 1:
# SR1: 2.0211 (Target: 1.0000) - Met
# SR2: 0.3480 (Target: 0.3000) - Met
# Pair 2:
# SR1: 1.3893 (Target: 1.0000) - Met
# SR2: 0.4195 (Target: 0.3000) - Met
# Pair 3:
# SR1: 2.3068 (Target: 1.0000) - Met
# SR2: 0.1776 (Target: 0.3000) - Not Met
# ---
#
# Best Reward Results =====
# Secrecy Rate: 7.2001
# Total Legitimate Rate: 8.5642
# Total Eavesdropper Rate: 1.3641
# Secrecy Ratio (Secrecy/Legitimate): 0.8407
# Total Power: 20.0000W
# Sum of All Power Thresholds: 20.0000W
# Constraint Satisfaction: 100.0%
#
# ===== Power Allocations =====
# Pair 1:
# P1: 2.2740 / PT1: 4.3510
# P2: 1.9945 / PT2: 3.4879
# Pair 2:
# P1: 3.0753 / PT1: 5.4917
# P2: 1.4896 / PT2: 2.6600
# Pair 3:
# P1: 1.3130 / PT1: 2.0448
# P2: 1.2615 / PT2: 1.9646
# Pn: 8.5921
#
# ===== Secrecy Rate Constraints =====
# Pair 1:
# SR1: 1.9704 (Target: 1.0000) - Met
# SR2: 0.4809 (Target: 0.3000) - Met
# Pair 2:
# SR1: 1.5582 (Target: 1.0000) - Met
# SR2: 0.5742 (Target: 0.3000) - Met
# Pair 3:
# SR1: 2.2245 (Target: 1.0000) - Met
# SR2: 0.3919 (Target: 0.3000) - Met
# Training completed!
